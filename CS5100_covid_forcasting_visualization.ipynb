# %% [markdown]
# <a href="https://colab.research.google.com/github/jiaqiwang0/CS5100/blob/ashley/CS5100_covid_forcasting_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import re

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import folium

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
path = '/content/drive/My Drive/CS5100 Final Project/data'

# %%
cases = ['Confirmed', 'Deaths', 'Recovered', 'Active']
locations = ['Lat', 'Long']

cleaned_data = pd.read_csv(path+'/time_series_covid19_cleaned_global .csv')
cleaned_data[['Province/State']] = cleaned_data[['Province/State']].fillna('')
cleaned_data[cases] = cleaned_data[cases].fillna(0)
cleaned_data[locations] = cleaned_data[locations].fillna(0)

cleaned_data[:]
# Out:
#        Province/State Country/Region        Lat        Long        Date  \
# 0                        Afghanistan  33.939110   67.709953  2020-01-22
# 1                            Albania  41.153300   20.168300  2020-01-22
# 2                            Algeria  28.033900    1.659600  2020-01-22
# 3                            Andorra  42.506300    1.521800  2020-01-22
# 4                             Angola -11.202700   17.873900  2020-01-22
# ...               ...            ...        ...         ...         ...
# 152587                     Venezuela   6.423800  -66.589700  2021-08-04
# 152588                       Vietnam  14.058324  108.277199  2021-08-04
# 152589                         Yemen  15.552727   48.516388  2021-08-04
# 152590                        Zambia -13.133897   27.849332  2021-08-04
# 152591                      Zimbabwe -19.015438   29.154857  2021-08-04
#
#         Confirmed  Deaths  Recovered  Active             WHO Region
# ...

# %% [markdown]
# # **Analysis and Visualization**

# %% [markdown]
# ## 1. Various Type of Cases Worldwide
# According to the data set we have, we can visualize the total number of various types of cases worldwide. In this part, we will mainly include four types of cases, which are confirmed cases, death cases, recovered cases and active cases. By delivering these outcomes, we could have a better vision of how Covid cases look like over the world and prepare for the following data learning and analyzing.

# %% [markdown]
# ### 1.1 Confirmed Cases Worldwide

# %%
# confirmed cases worldwide
confirmied_cases = pd.DataFrame(cleaned_data.groupby('Country/Region')['Confirmed'].sum())
confirmied_cases['Country/Region'] = confirmied_cases.index

global_confirmied_cases = confirmied_cases[['Country/Region','Confirmed']]

fig = px.bar(global_confirmied_cases.sort_values('Confirmed',ascending=False)[:20][::-1],x='Confirmed',y='Country/Region',title='Confirmed Cases Worldwide',text='Confirmed', height=900, orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 1.2 Deaths Cases Worldwide

# %%
# death cases worldwide
death_cases = pd.DataFrame(cleaned_data.groupby('Country/Region')['Deaths'].sum())
death_cases['Country/Region'] = death_cases.index

global_death_cases = death_cases[['Country/Region','Deaths']]

fig = px.bar(global_death_cases.sort_values('Deaths',ascending=False)[:20][::-1],x='Deaths',y='Country/Region',title='Deaths Cases Worldwide',text='Deaths', height=900, orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 1.3 Recovered Cases Worldwide

# %%
# recovered cases worldwide
recovered_cases = pd.DataFrame(cleaned_data.groupby('Country/Region')['Recovered'].sum())
recovered_cases['Country/Region'] = recovered_cases.index

global_recovered_cases = recovered_cases[['Country/Region','Recovered']]

fig = px.bar(global_recovered_cases.sort_values('Recovered',ascending=False)[:20][::-1],x='Recovered',y='Country/Region',title='Recovered Cases Worldwide',text='Recovered', height=900, orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 1.4 Active Cases Worldwide

# %%
# active cases worldwide
active_cases = pd.DataFrame(cleaned_data.groupby('Country/Region')['Active'].sum())
active_cases['Country/Region'] = active_cases.index

global_active_cases = active_cases[['Country/Region','Active']]

fig = px.bar(global_active_cases.sort_values('Active',ascending=False)[:20][::-1],x='Active',y='Country/Region',title='Active Cases Worldwide',text='Active', height=900, orientation='h')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# > By the bar graphs, we can understand that:
# 1. US, Brazil, Russia and India are in both of top 4 places global confirmed cases and recovered cases
# 2. US, United Kindom, Brazil and Italy are in top 4 places of global death cases
# 3. US, Brazil, United Kingdom and Russia are in top 4 places of global active cases

# %% [markdown]
# ## 2. Spread of Coronavirus over Time Globally and Regionally
# To display the spread of Covid over time, we will utilize scatter plots, where the x-axis represents the time period and the y-axis represents the total number of cases. In this part, we will show the spread of Covid over time in the following regions: Worldwide, China, Italy, Iran, South Korea, Spain and the rest of the world. For each graph, we will also include four categories of cases, which are confirmed, death, recovered and active.

# %% [markdown]
# 2.1 Global Spread of the Covid-19 Over Time

# %%
date_1 = cleaned_data.groupby('Date')['Confirmed'].sum().reset_index()
date_2 = cleaned_data.groupby('Date')['Deaths'].sum().reset_index()
date_3 = cleaned_data.groupby('Date')['Recovered'].sum().reset_index()
date_4 = cleaned_data.groupby('Date')['Active'].sum().reset_index()

fig = make_subplots(rows=1, cols=4, subplot_titles=("Comfirmed", "Deaths", "Recovered",'Active'))

trace1 = go.Scatter(
                x=date_1['Date'],
                y=date_1['Confirmed'],
                name="Confirmed",
                mode='lines',
                line_color='orange',
                opacity=0.8)

trace2 = go.Scatter(
                x=date_2['Date'],
                y=date_2['Deaths'],
                name="Deaths",
                mode='lines',
                line_color='red',
                opacity=0.8)

trace3 = go.Scatter(
                x=date_3['Date'],
                y=date_3['Recovered'],
                name="Recovered",
                mode='lines',
                line_color='green',
                opacity=0.8)

trace4 = go.Scatter(
                x=date_4['Date'],
                y=date_4['Active'],
                name="Active",
                mode='lines',
                line_color='blue',
                opacity=0.8)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)
fig.append_trace(trace4, 1, 4)
fig.update_layout(template="plotly_dark",title_text = '<b>Global Spread of the Coronavirus Over Time </b>', font=dict(color='white'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 2.2 China's Spread of the Covid-19 Over Time

# %%
grouped_china = cleaned_data[cleaned_data['Country/Region'] == "China"].reset_index()

grouped_china_1 = grouped_china.groupby('Date')['Confirmed'].sum().reset_index()
grouped_china_2 = grouped_china.groupby('Date')['Deaths'].sum().reset_index()
grouped_china_3 = grouped_china.groupby('Date')['Recovered'].sum().reset_index()
grouped_china_4 = grouped_china.groupby('Date')['Active'].sum().reset_index()

fig = make_subplots(rows=1, cols=4, subplot_titles=("Comfirmed", "Deaths", "Recovered",'Active'))

trace1 = go.Scatter(
                x=grouped_china_1['Date'],
                y=grouped_china_1['Confirmed'],
                name="Confirmed",
                line_color='orange',
                mode='lines',
                opacity=0.8)

trace2 = go.Scatter(
                x=grouped_china_2['Date'],
                y=grouped_china_2['Deaths'],
                name="Deaths",
                line_color='red',
                mode='lines',
                opacity=0.8)

trace3 = go.Scatter(
                x=grouped_china_3['Date'],
                y=grouped_china_3['Recovered'],
                name="Recovered",
                mode='lines',
                line_color='green',
                opacity=0.8)

trace4 = go.Scatter(
                x=grouped_china_4['Date'],
                y=grouped_china_4['Active'],
                name="Active",
                line_color='blue',
                mode='lines',
                opacity=0.8)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)
fig.append_trace(trace4, 1, 4)
fig.update_layout(template="plotly_dark",title_text = '<b>Spread of the Coronavirus Over Time in CHINA (TOP 1)</b>',
                  font=dict(family="Arial, Balto, Courier New, Droid Sans",color='white'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 2.3 Italy's Spread of the Covid-19 Over Time

# %%
grouped_italy = cleaned_data[cleaned_data['Country/Region'] == "Italy"].reset_index()

grouped_italy_1 = grouped_italy.groupby('Date')['Confirmed'].sum().reset_index()
grouped_italy_2 = grouped_italy.groupby('Date')['Deaths'].sum().reset_index()
grouped_italy_3 = grouped_italy.groupby('Date')['Recovered'].sum().reset_index()
grouped_italy_4 = grouped_italy.groupby('Date')['Active'].sum().reset_index()

fig = make_subplots(rows=1, cols=4, subplot_titles=("Comfirmed", "Deaths", "Recovered",'Active'))

trace1 = go.Scatter(
                x=grouped_italy_1['Date'],
                y=grouped_italy_1['Confirmed'],
                name="Confirmed",
                line_color='orange',
                mode='lines',
                opacity=0.8)

trace2 = go.Scatter(
                x=grouped_italy_2['Date'],
                y=grouped_italy_2['Deaths'],
                name="Deaths",
                line_color='red',
                mode='lines',
                opacity=0.8)

trace3 = go.Scatter(
                x=grouped_italy_3['Date'],
                y=grouped_italy_3['Recovered'],
                name="Recovered",
                mode='lines',
                line_color='green',
                opacity=0.8)

trace4 = go.Scatter(
                x=grouped_italy_4['Date'],
                y=grouped_italy_4['Active'],
                name="Active",
                line_color='blue',
                mode='lines',
                opacity=0.8)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)
fig.append_trace(trace4, 1, 4)
fig.update_layout(template="plotly_dark",title_text = '<b>Global Spread of the Coronavirus Over Time in ITALY (TOP 2)</b>',
                  font=dict(family="Arial, Balto, Courier New, Droid Sans",color='white'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 2.4 Iran's Spread of the Covid-19 Over Time

# %%
grouped_iran = cleaned_data[cleaned_data['Country/Region'] == "Iran"].reset_index()

grouped_iran_1 = grouped_iran.groupby('Date')['Confirmed'].sum().reset_index()
grouped_iran_2 = grouped_iran.groupby('Date')['Deaths'].sum().reset_index()
grouped_iran_3 = grouped_iran.groupby('Date')['Recovered'].sum().reset_index()
grouped_iran_4 = grouped_iran.groupby('Date')['Active'].sum().reset_index()

fig = make_subplots(rows=1, cols=4, subplot_titles=("Comfirmed", "Deaths", "Recovered",'Active'))

trace1 = go.Scatter(
                x=grouped_iran_1['Date'],
                y=grouped_iran_1['Confirmed'],
                name="Confirmed",
                line_color='orange',
                mode='lines',
                opacity=0.8)

trace2 = go.Scatter(
                x=grouped_iran_2['Date'],
                y=grouped_iran_2['Deaths'],
                name="Deaths",
                line_color='red',
                mode='lines',
                opacity=0.8)

trace3 = go.Scatter(
                x=grouped_iran_3['Date'],
                y=grouped_iran_3['Recovered'],
                name="Recovered",
                mode='lines',
                line_color='green',
                opacity=0.8)

trace4 = go.Scatter(
                x=grouped_iran_4['Date'],
                y=grouped_iran_4['Active'],
                name="Active",
                line_color='blue',
                mode='lines',
                opacity=0.8)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)
fig.append_trace(trace4, 1, 4)
fig.update_layout(template="plotly_dark",title_text = '<b>Global Spread of the Coronavirus Over Time in ITALY (TOP 2)</b>',
                  font=dict(family="Arial, Balto, Courier New, Droid Sans",color='white'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 2.5 South Korea's Spread of the Covid-19 Over Time

# %%
grouped_korea = cleaned_data[cleaned_data['Country/Region'] == "South Korea"].reset_index()

grouped_korea_1 = grouped_korea.groupby('Date')['Confirmed'].sum().reset_index()
grouped_korea_2 = grouped_korea.groupby('Date')['Deaths'].sum().reset_index()
grouped_korea_3 = grouped_korea.groupby('Date')['Recovered'].sum().reset_index()
grouped_korea_4 = grouped_korea.groupby('Date')['Active'].sum().reset_index()

fig = make_subplots(rows=1, cols=4, subplot_titles=("Comfirmed", "Deaths", "Recovered",'Active'))

trace1 = go.Scatter(
                x=grouped_korea_1['Date'],
                y=grouped_korea_1['Confirmed'],
                name="Confirmed",
                line_color='orange',
                mode='lines',
                opacity=0.8)

trace2 = go.Scatter(
                x=grouped_korea_2['Date'],
                y=grouped_korea_2['Deaths'],
                name="Deaths",
                line_color='red',
                mode='lines',
                opacity=0.8)

trace3 = go.Scatter(
                x=grouped_korea_3['Date'],
                y=grouped_korea_3['Recovered'],
                name="Recovered",
                mode='lines',
                line_color='green',
                opacity=0.8)

trace4 = go.Scatter(
                x=grouped_korea_4['Date'],
                y=grouped_korea_4['Active'],
                name="Active",
                line_color='blue',
                mode='lines',
                opacity=0.8)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)
fig.append_trace(trace4, 1, 4)
fig.update_layout(template="plotly_dark",title_text = '<b>Global Spread of the Coronavirus Over Time in ITALY (TOP 2)</b>',
                  font=dict(family="Arial, Balto, Courier New, Droid Sans",color='white'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 2.6 Spain's Spread of the Covid-19 Over Time

# %%
grouped_spain = cleaned_data[cleaned_data['Country/Region'] == "Spain"].reset_index()

grouped_spain_1 = grouped_spain.groupby('Date')['Confirmed'].sum().reset_index()
grouped_spain_2 = grouped_spain.groupby('Date')['Deaths'].sum().reset_index()
grouped_spain_3 = grouped_spain.groupby('Date')['Recovered'].sum().reset_index()
grouped_spain_4 = grouped_spain.groupby('Date')['Active'].sum().reset_index()

fig = make_subplots(rows=1, cols=4, subplot_titles=("Comfirmed", "Deaths", "Recovered",'Active'))

trace1 = go.Scatter(
                x=grouped_spain_1['Date'],
                y=grouped_spain_1['Confirmed'],
                name="Confirmed",
                line_color='orange',
                mode='lines',
                opacity=0.8)

trace2 = go.Scatter(
                x=grouped_spain_2['Date'],
                y=grouped_spain_2['Deaths'],
                name="Deaths",
                line_color='red',
                mode='lines',
                opacity=0.8)

trace3 = go.Scatter(
                x=grouped_spain_3['Date'],
                y=grouped_spain_3['Recovered'],
                name="Recovered",
                mode='lines',
                line_color='green',
                opacity=0.8)

trace4 = go.Scatter(
                x=grouped_spain_4['Date'],
                y=grouped_spain_4['Active'],
                name="Active",
                line_color='blue',
                mode='lines',
                opacity=0.8)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)
fig.append_trace(trace4, 1, 4)
fig.update_layout(template="plotly_dark",title_text = '<b>Global Spread of the Coronavirus Over Time in ITALY (TOP 2)</b>',
                  font=dict(family="Arial, Balto, Courier New, Droid Sans",color='white'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 2.6 Rest of the World Spread of the Covid-19 Over Time

# %%
grouped_rest = cleaned_data[~cleaned_data['Country/Region'].isin(['China', 'Italy', 'iran', 'South Korea', 'Spain'])].reset_index()

grouped_rest_1 = grouped_rest.groupby('Date')['Confirmed'].sum().reset_index()
grouped_rest_2 = grouped_rest.groupby('Date')['Deaths'].sum().reset_index()
grouped_rest_3 = grouped_rest.groupby('Date')['Recovered'].sum().reset_index()
grouped_rest_4 = grouped_rest.groupby('Date')['Active'].sum().reset_index()

fig = make_subplots(rows=1, cols=4, subplot_titles=("Comfirmed", "Deaths", "Recovered",'Active'))

trace1 = go.Scatter(
                x=grouped_rest_1['Date'],
                y=grouped_rest_1['Confirmed'],
                name="Confirmed",
                line_color='orange',
                mode='lines',
                opacity=0.8)

trace2 = go.Scatter(
                x=grouped_rest_2['Date'],
                y=grouped_rest_2['Deaths'],
                name="Deaths",
                line_color='red',
                mode='lines',
                opacity=0.8)

trace3 = go.Scatter(
                x=grouped_rest_3['Date'],
                y=grouped_rest_3['Recovered'],
                name="Recovered",
                mode='lines',
                line_color='green',
                opacity=0.8)

trace4 = go.Scatter(
                x=grouped_rest_4['Date'],
                y=grouped_rest_4['Active'],
                name="Active",
                line_color='blue',
                mode='lines',
                opacity=0.8)

fig.append_trace(trace1, 1, 1)
fig.append_trace(trace2, 1, 2)
fig.append_trace(trace3, 1, 3)
fig.append_trace(trace4, 1, 4)
fig.update_layout(template="plotly_dark",title_text = '<b>Global Spread of the Coronavirus Over Time in ITALY (TOP 2)</b>',
                  font=dict(family="Arial, Balto, Courier New, Droid Sans",color='white'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
